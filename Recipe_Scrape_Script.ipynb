# %% [markdown]
# # Scrape Recipe Details from Epicurious

# %%
from bs4 import BeautifulSoup
from splinter import Browser
import time
from time import sleep
import pandas as pd
import json
import requests

# %%
# load the recipe list into a data frame
recipe_list_filepath = 'resources/data/recipe_list.csv'
df_recipe_list = pd.read_csv(recipe_list_filepath)

df_recipe_list.head()
# Out:
#       source  year                                              title  \
# 0  editorial  2019  Okonomiyaki (“As You Like It”) Pancakes With B...
# 1  editorial  2019       Salmon Confit with Lime, Juniper, and Fennel
# 2  editorial  2019  Coconut-Braised Chickpeas with Sweet Potatoes ...
# 3  editorial  2019                          Crispy Sheet-Pan Broccoli
# 4  editorial  2019                                       Prawn Moilee
#
#                                                  url
# 0  /recipes/food/views/okonomiyaki-as-you-like-it...
# 1  /recipes/food/views/salmon-confit-with-lime-ju...
# 2  /recipes/food/views/coconut-braised-chickpeas-...
# 3      /recipes/food/views/crispy-sheet-pan-broccoli
# 4  /recipes/food/views/prawn-moilee-south-indian-...

# %%
# add a new columns to track whether it's a recipe and that it has been scraped
df_recipe_list['is_recipe'] = ''
df_recipe_list['scraped'] = ''
df_recipe_list.head()
# Out:
#       source  year                                              title  \
# 0  editorial  2019  Okonomiyaki (“As You Like It”) Pancakes With B...
# 1  editorial  2019       Salmon Confit with Lime, Juniper, and Fennel
# 2  editorial  2019  Coconut-Braised Chickpeas with Sweet Potatoes ...
# 3  editorial  2019                          Crispy Sheet-Pan Broccoli
# 4  editorial  2019                                       Prawn Moilee
#
#                                                  url is_recipe scraped
# 0  /recipes/food/views/okonomiyaki-as-you-like-it...
# 1  /recipes/food/views/salmon-confit-with-lime-ju...
# 2  /recipes/food/views/coconut-braised-chickpeas-...
# 3      /recipes/food/views/crispy-sheet-pan-broccoli
# 4  /recipes/food/views/prawn-moilee-south-indian-...

# %%
df_recipe_list[df_recipe_list['is_recipe'] == '']
# Out:
#           source  year                                              title  \
# 0      editorial  2019  Okonomiyaki (“As You Like It”) Pancakes With B...
# 1      editorial  2019       Salmon Confit with Lime, Juniper, and Fennel
# 2      editorial  2019  Coconut-Braised Chickpeas with Sweet Potatoes ...
# 3      editorial  2019                          Crispy Sheet-Pan Broccoli
# 4      editorial  2019                                       Prawn Moilee
# 5      editorial  2019                   Cardamom-Pistachio Bûche de Noël
# 6      editorial  2019                                       Tonnato Eggs
# 7      editorial  2019                          Chickpea-Mushroom Burgers
# 8      editorial  2019                    Kimchi Soup With Tofu and Clams
# 9      editorial  2019  Roasted Cabbage Steaks With Crispy Chickpeas a...
# 10     editorial  2019         Creamy Squash Risotto With Toasted Pepitas
# 11     editorial  2019                          Winter Salad Hummus Bowls
# 12     editorial  2019                               Seedy Power Sprinkle
# 13     editorial  2019                                        Salad Pasta
# 14     editorial  2019                               Martini-on-the-Rocks
# 15     editorial  2019                                         Oystertini
# 16     editorial  2019                                   Puritan Cocktail
# 17     editorial  2019                                       Tuxedo No. 2
# 18     editorial  2019                                  Obituary Cocktail
# 19     editorial  2019                                Classic Dry Martini
# 20     editorial  2019           Chilaquiles With Bacon, Eggs, and Cheese
# 21     editorial  2019                  Instant Pot Tequila Lime Carnitas
# 22     editorial  2019             Instant Pot Chicken Parmesan Meatballs
# 23     editorial  2019                             Spicy Chickpea Poppers
# 24     editorial  2019                                      Pandora’s Box
# 25     editorial  2019                                    Islay and Olive
# 26     editorial  2019                                        Sneaky Peat
# 27     editorial  2019    Pansit Palabok (Rice Noodles with Shrimp Sauce)
# 28     editorial  2019                     Bubble and Squeak With Stilton
# 29     editorial  2019           Spiced Pomegranate and Orange Glazed Ham
# ...          ...   ...                                                ...
# 36392  editorial  2004                                Minted Lamb Patties
# 36393  editorial  2004   Marmalade-Glazed Ham with Sweet Orange-Tea Sauce
# 36394  editorial  2004                         Beef and Broccoli Stir-Fry
# 36395  editorial  2004  Mustard Seed-Crusted Salmon with Mustard Cream...
# 36396  editorial  2004                                            Jumbles
# 36397  editorial  2004                            Southwestern Tofu Wraps
# 36398  editorial  2004                                           Untitled
# 36399  editorial  2004                                  Deluxe Kir Royale
# 36400  editorial  2004               Oatmeal, Almond, Pear and Plum Crisp
# 36401  editorial  2004                     Chicken with Lemon-Basil Sauce
# 36402  editorial  2003                               Homemade Pizza Dough
# 36403  editorial  2003                                  Veiled Farm Girls
# 36404  editorial  2003                                Sweet Mustard Sauce
# 36405  editorial  2003          Mussels with Aquavit, Cream, and Tarragon
# 36406  editorial  2003                                     Fish Dumplings
# 36407  editorial  2003                  Gravlaks with Sweet Mustard Sauce
# 36408  editorial  2003                                   Bergen Fish Soup
# 36409  editorial  2000    Rib-Eye Steak au Poivre with Balsamic Reduction
# 36410  editorial  2000                             Black-Bean Quesadillas
# 36411  editorial  1999                   Venison Chili with Snowcap Beans
# 36412  editorial  1999             Café Brenda Black Bean Vegetable Chili
# 36413  editorial  1999                                  Havana Moon Chili
# 36414  editorial  1999                 Spinach with Pine Nuts and Raisins
# 36415  editorial  1998                 Braised Meat with Butternut Squash
# 36416  editorial  1998       Roast Chicken with Orange, Lemon, and Ginger
# 36417  editorial  1998                              Massimo's "Farinella"
# 36418  editorial  1998          Franco's Pasta with Zucchini and Potatoes
# 36419  editorial  1998              Jennie June's Brown Fricassée Chicken
# 36420  editorial  1998                                  "Tuna" of Chicken
# 36421  editorial  1998     Zingerman's Ann Arbor Mushroom and Barley Soup
#
#                                                      url is_recipe scraped
# 0      /recipes/food/views/okonomiyaki-as-you-like-it...
# 1      /recipes/food/views/salmon-confit-with-lime-ju...
# 2      /recipes/food/views/coconut-braised-chickpeas-...
# 3          /recipes/food/views/crispy-sheet-pan-broccoli
# 4      /recipes/food/views/prawn-moilee-south-indian-...
# 5      /recipes/food/views/cardamom-pistachio-buche-d...
# 6                       /recipes/food/views/tonatto-eggs
# 7          /recipes/food/views/chickpea-mushroom-burgers
# 8      /recipes/food/views/kimchi-soup-with-tofu-and-...
# 9      /recipes/food/views/roasted-cabbage-steaks-wit...
# 10     /recipes/food/views/creamy-squash-risotto-with...
# 11         /recipes/food/views/winter-salad-hummus-bowls
# 12              /recipes/food/views/seedy-power-sprinkle
# 13                       /recipes/food/views/salad-pasta
# 14     /recipes/food/views/martini-on-the-rocks-easy-...
# 15     /recipes/food/views/oystertini-oyster-martini-...
# 16     /recipes/food/views/puritan-cocktail-martini-v...
# 17     /recipes/food/views/tuxedo-no-2-martini-cockta...
# 18     /recipes/food/views/obituary-cocktail-martini-...
# 19        /recipes/food/views/classic-dry-martini-237574
# 20     /recipes/food/views/chilaquiles-with-bacon-egg...
# 21     /recipes/food/views/instant-pot-tequila-lime-c...
# 22     /recipes/food/views/instant-pot-chicken-parmes...
# 23            /recipes/food/views/spicy-chickpea-poppers
# 24     /recipes/food/views/pandoras-box-shibuya-honey...
# 25     /recipes/food/views/islay-and-olive-batched-di...
# 26     /recipes/food/views/sneaky-peat-cranberry-scot...
# 27     /recipes/food/views/pansit-palabok-rice-noodle...
# 28     /recipes/food/views/bubble-and-squeak-with-sti...
# 29     /recipes/food/views/spiced-pomegranate-and-ora...
# ...                                                  ...       ...     ...
# 36392         /recipes/food/views/minted-lamb-patties-18
# 36393  /recipes/food/views/marmalade-glazed-ham-with-...
# 36394  /recipes/food/views/beef-and-broccoli-stir-fry-23
# 36395  /recipes/food/views/mustard-seed-crusted-salmo...
# 36396                   /recipes/food/views/jumbles-6004
# 36397  /recipes/food/views/southwestern-tofu-wraps-10...
# 36398                /recipes/food/views/untitled-105056
# 36399       /recipes/food/views/deluxe-kir-royale-102813
# 36400  /recipes/food/views/oatmeal-almond-pear-and-pl...
# 36401  /recipes/food/views/chicken-with-lemon-basil-s...
# 36402    /recipes/food/views/homemade-pizza-dough-108197
# 36403       /recipes/food/views/veiled-farm-girls-235002
# 36404     /recipes/food/views/sweet-mustard-sauce-234999
# 36405  /recipes/food/views/mussels-with-aquavit-cream...
# 36406          /recipes/food/views/fish-dumplings-234997
# 36407  /recipes/food/views/gravlaks-with-sweet-mustar...
# 36408        /recipes/food/views/bergen-fish-soup-234996
# 36409  /recipes/food/views/rib-eye-steak-au-poivre-wi...
# 36410  /recipes/food/views/black-bean-quesadillas-239962
# 36411  /recipes/food/views/venison-chili-with-snowcap...
# 36412  /recipes/food/views/cafe-brenda-black-bean-veg...
# 36413       /recipes/food/views/havana-moon-chili-100551
# 36414  /recipes/food/views/spinach-with-pine-nuts-and...
# 36415  /recipes/food/views/braised-meat-with-butternu...
# 36416  /recipes/food/views/roast-chicken-with-orange-...
# 36417       /recipes/food/views/massimos-farinella-13223
# 36418  /recipes/food/views/francos-pasta-with-zucchin...
# 36419  /recipes/food/views/jennie-junes-brown-fricass...
# 36420         /recipes/food/views/-tuna-of-chicken-13224
# 36421  /recipes/food/views/zingermans-ann-arbor-mushr...
#
# [36422 rows x 6 columns]

# %%
# (not scraped: special equipment, preparation, menus, related content)
def scrape_general_info(soup, recipe):
    '''
    Takes the soup object and dictionary of recipe. Parses out general recipe info and
    adds to recipe dictionary. Missing values will have a value of None.
    
    '''

    # parse the bits
    try:
        title = soup.find('div', class_='title-source').h1.text
    except Exception:
        title = None
    
    try:
        author = soup.find(class_='contributor')['title'].strip()
    except Exception:
        author = None
        
    try:
        date = soup.find(class_="pub-date").text
    except Exception:
        date = None
    
    try:
        month = date.split()[0]
    except Exception:
        month = None
    
    try:
        year = int(date.split()[1])
    except Exception:       
        year = None
        
    try: 
        rating = float(soup.find(class_="user-interactions").meta['content'])
    except Exception:
        rating = None
        
    try:
        reviews = int(soup.find(class_="reviews-count").text)
    except Exception:
        reviews = None
        
    try:
        make_again = soup.find('div', class_="prepare-again-rating").span.text
    except Exception:
        make_again = None
        
    try:
        active_time = soup.find('dd', class_="active-time").text
    except Exception:
        active_time = None
        
    try:
        image_url = soup.find('img', class_='photo loaded')['srcset']
    except Exception:
        image_url = None
        
    # add bits to recipe dictionary
    recipe['title'] = title
    recipe['author'] = author
    recipe['date'] = date
    recipe['month'] = month
    recipe['year'] = year
    recipe['rating'] = rating
    recipe['reviews'] = reviews
    recipe['make_again'] = make_again
    recipe['active_time'] = active_time
    recipe['image_url'] = image_url

# %%
def scrape_ingredients(soup, recipe):
    '''
    Takes the soup object and dictionary of recipe. Parses out the ingredients into a list
    and adds to receipe.
    
    '''
    try:
        ingredients = []
        
        ingredient_list = soup.find_all('li', class_="ingredient")
        
        for ingredient_item in ingredient_list:
            ingredients.append(ingredient_item.text)
        
        recipe['ingredients'] = ingredients
    except Exception:
        recipe['ingredients'] = None

# %%
def scrape_nutritional_info(soup, recipe):
    '''
    Takes the soup object and dictionary of recipe. Parses out the nutrional info into a dictionary
    and adds to receipe.
    
    '''
    nutrition = dict()

    try:
        nutrition['cal'] = int(soup.find('span', class_="nutri-data", itemprop="calories").text)
    except Exception:
        nutrition['cal'] = None
    
    try: 
        nutrition['carb'] = (soup.find('span', class_="nutri-data", itemprop="carbohydrateContent").text)
    except Exception:
        nutrition['carb'] = None
        
    try:
        nutrition['fat'] = soup.find('span', class_="nutri-data", itemprop="fatContent").text
    except Exception:
        nutrition['fat'] = None
        
    try:
        nutrition['protein'] = soup.find('span', class_="nutri-data", itemprop="proteinContent").text
    except Exception:
        nutrition['protein'] = None
        
    try:
        nutrition['sat_fat'] = soup.find('span', class_="nutri-data", itemprop="saturatedFatContent").text
    except Exception:
        nutrition['sat_fat'] = None
        
    try:
        nutrition['sodium'] = soup.find('span', class_="nutri-data", itemprop="sodiumContent").text
    except Exception:
        nutrition['sodium'] = None
        
    try:
        nutrition['polyunsat_fat'] = soup.findAll('span', class_="nutri-data")[6].text # no attr = itemprop
    except Exception:
        nutrition['polyunsat_fat'] = None
        
    try:
        nutrition['fiber'] = soup.find('span', class_="nutri-data", itemprop="fiberContent").text
    except Exception:
        nutrition['fiber'] = None
        
    try:
        nutrition['monounsat_fat'] = soup.findAll('span', class_="nutri-data")[8].text # no attr = itemprop
    except Exception:
        nutrition['monounsat_fat'] = None
    
    try:
        nutrition['cholesterol'] = soup.findAll('span', class_="nutri-data")[9].text # no attr = itemprop
    except Exception:
        nutrition['cholesterol'] = None
        
    try:
        nutrition['servings'] = soup.find(class_="per-serving").text
    except Exception:
        nutrition['servings'] = None

    recipe['nutrition'] = nutrition # dict of dict [int, int]

# %%
def scrape_tags(soup, recipe):
    '''
    Takes the soup object and dictionary of recipe. Parses out the tag info into a dictionary
    and adds to receipe.
    
    '''
    # dictionary of tags
    tags = dict()
        
    try:
        tag_list = soup.find('dl', class_='tags').findAll('a')

        # loop through each tag and add values to tags dictionary
        for tag in tag_list:
            # this removes the first forward slash from the href tag and then splits into list
            item = tag['href'][1:].split("/")
    
            if item[0] not in tags:
                tags[item[0]] = [item[1]]
            else:
                tags[item[0]].append(item[1])
    except Exception:
        tags = None
        
    recipe['tags'] = tags

# %%
# define recipe urls and years to search
root_url = "https://www.epicurious.com"

# %%
# define list of all recipes
all_recipes = []

# %%
# start up the browser
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# loop through all items in the dataframe and pull details
for index, row in df_recipe_list.iterrows(): 
    print(f'Processing index {index}')
    if index > 50:
        break
    else:
        # navigate to recipe url
        url = root_url + row.url
        
        r = requests.get(url)
        
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            
        
#         browser.visit(url)
#         sleep(1)
        
#         # parse with beautiful soup
#         html = browser.html
#         soup = BeautifulSoup(html, 'html.parser')
        
            # confirm it is a recipe before trying to parse
            if 'recipe-detail' in soup.body['class']:
                # is a recipe, let's scrape!
                df_recipe_list.iloc[index, df_recipe_list.columns.get_loc('is_recipe')] = 1

                # create recipe dictionary
                recipe = dict()  
                recipe['url'] = url

                #scrape bits we need
                scrape_general_info(soup, recipe)
                scrape_ingredients(soup, recipe)
                scrape_nutritional_info(soup, recipe)
                scrape_tags(soup, recipe)

                # add completed recipe to list
                all_recipes.append(recipe)
                df_recipe_list.iloc[index, df_recipe_list.columns.get_loc('scraped')] = 1

            else:
                # not a recipe. mark as such and move on
                df_recipe_list.iloc[index, df_recipe_list.columns.get_loc('is_recipe')] = 0
                
        else:
            print(f'Response code {r.status_code} for index {index} and url {url}')

#         print(url)
        
#         df_recipe_list.iloc[index, df.columns.get_loc('is_recipe')] = 'Y'
        
print('out of loop')
# Out:
# Processing index 0
# Processing index 1
# Processing index 2
# Processing index 3
# Processing index 4
# Processing index 5
# Processing index 6
# Processing index 7
# Processing index 8
# Processing index 9
# Processing index 10
# Processing index 11
# Processing index 12
# Processing index 13
# Processing index 14
# Processing index 15
# Processing index 16
# Processing index 17
# Processing index 18
# Processing index 19
# Processing index 20
# Processing index 21
# Processing index 22
# Processing index 23
# Processing index 24
# Processing index 25
# Processing index 26
# Processing index 27
# Processing index 28
# Processing index 29
# Processing index 30
# Processing index 31
# Processing index 32
# Processing index 33
# Processing index 34
# Processing index 35
# Processing index 36
# Processing index 37
# Processing index 38
# Processing index 39
# Processing index 40
# Processing index 41
# Processing index 42
# Processing index 43
# Processing index 44
# Processing index 45
# Processing index 46
# Processing index 47
# Processing index 48
# Processing index 49
# Processing index 50
# Processing index 51
# out of loop

# %%
all_recipes
# Out:
# [{'url': 'https://www.epicurious.com/recipes/food/views/okonomiyaki-as-you-like-it-pancakes-with-bonito-flakes',
#   'title': 'Okonomiyaki (“As You Like It”) Pancakes With Bonito Flakes ',
#   'author': 'Sonoko Sakai',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 3.5,
#   'reviews': 3,
#   'make_again': '100%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dfbeb3a8a7c8f0008b67fe6/6:4/w_274%2Ch_169/Japanese-Home-Cooking-Okonomiyaki-Recipe-121919.jpg',
#   'ingredients': ['1 ½ cups (180 g) all-purpose flour',
#    '1 teaspoon baking powder',
#    '¼ teaspoon sea salt',
#    '1 large egg, beaten',
#    '1¼ cups (296 ml) whole milk or milk of your choice',
#    '8 ounces (230 g) cabbage, thinly sliced',
#    '2 scallions, white and light green parts chopped',
#    '½ yellow, green, or red bell pepper, thinly sliced',
#    '4 tablespoons vegetable oil',
#    '8 ounces (230 g) boneless chicken, shrimp, crab, or sukiyaki-style beef or pork, cut into ½-inch (12 mm) pieces',
#    '2 tablespoons mayonnaise',
#    '2 tablespoon or more homemade or store-bought Tonkatsu Sauce',
#    '½ cup (4 g) bonito flakes',
#    '½ cup (4 g) crumbled nori'],
#   'nutrition': {'cal': 249,
#    'carb': '22 g(7%)',
#    'fat': '13 g(20%)',
#    'protein': '11 g(22%)',
#    'sat_fat': '2 g(12%)',
#    'sodium': '180 mg(8%)',
#    'polyunsat_fat': '3 g',
#    'fiber': '2 g(6%)',
#    'monounsat_fat': '7 g',
#    'cholesterol': '46 mg(15%)',
#    'servings': 'per serving (8 servings)'},
#   'tags': {'cuisine': ['japanese', 'asian'],
#    'type': ['pancake'],
#    'meal': ['dinner', 'breakfast'],
#    'ingredient': ['cabbage', 'green-onion-scallion', 'bell-pepper'],
#    'special-consideration': ['tree-nut-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/salmon-confit-with-lime-juniper-and-fennel',
#   'title': 'Salmon Confit with Lime, Juniper, and Fennel ',
#   'author': 'Melissa Clark',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dfa62b1730c1d000887ee04/6:4/w_274%2Ch_169/Salmon-Confit.jpg',
#   'ingredients': ['2 limes',
#    '½ teaspoon fine sea salt, plus more as needed',
#    '½ teaspoon freshly ground black pepper',
#    '4 dried juniper berries, lightly crushed with a mortar and pestle or the side of a heavy knife',
#    '½ teaspoon fennel seeds, lightly crushed with a mortar and pestle or the side of a heavy knife',
#    '4 (6- to 8-ounce) skinless salmon fillets',
#    '6 sprigs fresh marjoram or thyme',
#    'Extra-virgin olive oil, as needed',
#    '1 large fennel bulb, with fronds',
#    'Flaky sea salt, for serving'],
#   'nutrition': {'cal': 494,
#    'carb': '11 g(4%)',
#    'fat': '32 g(48%)',
#    'protein': '42 g(84%)',
#    'sat_fat': '7 g(34%)',
#    'sodium': '449 mg(19%)',
#    'polyunsat_fat': '8 g',
#    'fiber': '4 g(18%)',
#    'monounsat_fat': '11 g',
#    'cholesterol': '109 mg(36%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'tag': ['cookbooks', 'olive-oil'],
#    'ingredient': ['salmon', 'lime', 'fennel', 'thyme'],
#    'occasion': ['fall', 'winter'],
#    'meal': ['dinner']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/coconut-braised-chickpeas-with-sweet-potatoes-and-greens',
#   'title': 'Coconut-Braised Chickpeas with Sweet Potatoes and Greens ',
#   'author': 'David Tamarkin',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 3.5,
#   'reviews': 2,
#   'make_again': '100%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dfa5857e012cf00081db894/6:4/w_274%2Ch_169/Chickpea-Curry-with-Sweet-Potatoes-and-Greens.jpg',
#   'ingredients': ['½ cup slivered almonds',
#    '2 tablespoons coconut or vegetable oil',
#    '1 onion, thinly sliced',
#    '2 garlic cloves, finely chopped',
#    '1 tablespoon grated or finely chopped fresh ginger',
#    '1½ teaspoons curry powder',
#    '1 large bunch (about 8 ounces) greens, such as Swiss chard, kale, or collard greens, stems removed and leaves torn into medium-size pieces, washed, and shaken dry (there should be a little water still clinging to the leaves)',
#    '1 (15-ounce) can chickpeas, rinsed and drained',
#    '1 (13.5-ounce) can coconut milk',
#    '2 teaspoons kosher salt',
#    '4 Roasted Sweet Potato halves, cut into ½-inch pieces',
#    '1 tablespoon fresh lime juice, plus additional wedges for serving',
#    '½ cup chopped fresh cilantro leaves and tender stems, plus more for serving',
#    'Plain yogurt, for serving'],
#   'nutrition': {'cal': 618,
#    'carb': '62 g(21%)',
#    'fat': '37 g(58%)',
#    'protein': '16 g(32%)',
#    'sat_fat': '19 g(97%)',
#    'sodium': '1038 mg(43%)',
#    'polyunsat_fat': '4 g',
#    'fiber': '14 g(57%)',
#    'monounsat_fat': '11 g',
#    'cholesterol': '',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'tag': ['cookbooks'], 'ingredient': ['curry', 'coconut']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/crispy-sheet-pan-broccoli',
#   'title': 'Crispy Sheet-Pan Broccoli ',
#   'author': 'Mindy Fox',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 2,
#   'make_again': '100%',
#   'active_time': '5',
#   'image_url': 'https://assets.epicurious.com/photos/5df7c9f359ab0800097d5f57/6:4/w_274%2Ch_169/COOK90_RicottaBowl_RECIPE_121119_098.jpg',
#   'ingredients': ['3 large heads broccoli (3 ½ to 4 pounds total), trimmed, cut into florets with some stalk attached (cut the florets in half if large)',
#    '½ cup olive oil',
#    'Kosher salt',
#    'Freshly ground black pepper'],
#   'nutrition': {'cal': 218,
#    'carb': '19 g(6%)',
#    'fat': '15 g(22%)',
#    'protein': '8 g(16%)',
#    'sat_fat': '2 g(10%)',
#    'sodium': '696 mg(29%)',
#    'polyunsat_fat': '2 g',
#    'fiber': '8 g(31%)',
#    'monounsat_fat': '10 g',
#    'cholesterol': '',
#    'servings': 'per serving (8 servings)'},
#   'tags': {'ingredient': ['broccoli'],
#    'equipment': ['sheet-pan'],
#    'tag': ['olive-oil', 'cook90'],
#    'special-consideration': ['vegetarian', 'vegan', 'wheat-gluten-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/prawn-moilee-south-indian-shrimp-curry-with-coconut',
#   'title': 'Prawn Moilee ',
#   'author': 'Naved Nasir',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5df802dddb92460008bf992a/6:4/w_274%2Ch_169/Prawn-Moilee.jpg',
#   'ingredients': ['6 green chillies',
#    '55ml (about ¼ cup) vegetable oil',
#    '2 tsp. mustard seeds',
#    '30 fresh curry leaves',
#    '300g (2 cups) Spanish white onions, sliced (a little chunky is good)',
#    '15g (1 Tbsp.) garlic paste',
#    '15g (1 Tbsp.) ginger paste',
#    '2 tsp. fine sea salt',
#    '1 tsp. freshly ground black pepper',
#    '1¼ tsp. ground turmeric',
#    '25g (¼ cup) fresh root ginger, cut into matchsticks',
#    '400ml (about 2 cups) coconut milk',
#    '250ml (about 1 cup) coconut cream',
#    '24 large prawns',
#    '300g (about 1 ½ cups) medium tomatoes, cut into small bite-sized wedges',
#    'Lemon wedges, to serve'],
#   'nutrition': {'cal': 650,
#    'carb': '31 g(10%)',
#    'fat': '57 g(88%)',
#    'protein': '14 g(28%)',
#    'sat_fat': '39 g(194%)',
#    'sodium': '1052 mg(44%)',
#    'polyunsat_fat': '3 g',
#    'fiber': '7 g(26%)',
#    'monounsat_fat': '12 g',
#    'cholesterol': '53 mg(18%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'ingredient': ['shrimp',
#     'curry',
#     'chile-pepper',
#     'onion',
#     'ginger',
#     'garlic',
#     'coconut',
#     'tomato'],
#    'cuisine': ['indian']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/cardamom-pistachio-buche-de-noel',
#   'title': 'Cardamom-Pistachio Bûche de Noël ',
#   'author': 'Samantha Seneviratne',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 3.0,
#   'reviews': 4,
#   'make_again': '75%',
#   'active_time': '2 hours',
#   'image_url': 'https://assets.epicurious.com/photos/5deea0ab58b8fe0009567d50/6:4/w_274%2Ch_169/Bu%CC%82chedeNoe%CC%88l_HERO_112119_17670.jpg',
#   'ingredients': ['2 large egg whites, room temperature (reserve yolks)',
#    '1/4 tsp. cream of tartar',
#    '1/4 tsp. kosher salt',
#    '1/2 cup granulated sugar, divided',
#    'Unsweetened cocoa powder (for dusting)',
#    '2 oz. chopped bittersweet chocolate',
#    '6 oz. raw pistachios',
#    '1 3/4 cups whole milk',
#    '1 1/2 tsp. unflavored powdered gelatin',
#    '5 large egg yolks (from meringues and frosting)',
#    '1/2 cup granulated sugar',
#    '3/4 tsp. kosher salt',
#    '1/4 tsp. almond extract',
#    '3 large egg whites (reserve yolks)',
#    '2/3 cup granulated sugar',
#    '1/4 tsp. kosher salt',
#    '8 oz. chopped bittersweet chocolate',
#    '1 cup (2 sticks) unsalted butter, room temperature, cut into pieces',
#    '1 1/2 tsp. vanilla extract',
#    'Neutral oil or unsalted butter (for pan)',
#    '6 large eggs, room temperature, separated',
#    '1 3/4 cups granulated sugar, divided',
#    '1 tsp. vanilla extract',
#    '1 1/2 cups cake flour',
#    '1/2 tsp. baking powder',
#    '1/2 tsp. kosher salt',
#    '1/2 tsp. ground cardamom, divided',
#    '1 tsp. cream of tartar',
#    'Powdered sugar (for dusting)',
#    '1/3 cup brandy',
#    '8 oz. chopped dark chocolate',
#    '2 Tbsp. unsweetened cocoa powder',
#    '2 oz. raw pistachios, finely ground',
#    'Powdered sugar (for dusting)'],
#   'nutrition': {'cal': 889,
#    'carb': '102 g(34%)',
#    'fat': '48 g(74%)',
#    'protein': '15 g(30%)',
#    'sat_fat': '22 g(110%)',
#    'sodium': '377 mg(16%)',
#    'polyunsat_fat': '5 g',
#    'fiber': '6 g(24%)',
#    'monounsat_fat': '17 g',
#    'cholesterol': '215 mg(72%)',
#    'servings': 'per serving (12 servings)'},
#   'tags': {'occasion': ['christmas', 'christmas-eve'],
#    'type': ['cake'],
#    'ingredient': ['egg',
#     'cardamom',
#     'chocolate',
#     'pistachio',
#     'milk-cream',
#     'butter',
#     'vanilla',
#     'brandy'],
#    'meal': ['dessert'],
#    'cuisine': ['french'],
#    'technique': ['bake']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/tonatto-eggs',
#   'title': 'Tonnato Eggs ',
#   'author': 'Anna Stockwell',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': '30 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5de5747059ab0800097d5f10/6:4/w_274%2Ch_169/TonnatoEggs_RECIPE_112019_17268.jpg',
#   'ingredients': ['12 large eggs',
#    '1 (6-oz.) can oil-packed tuna',
#    '2 oil-packed anchovy fillets',
#    '1/2 cup mayonnaise',
#    '2 Tbsp. fresh lemon juice',
#    '2 Tbsp. capers, drained, divided',
#    '1/2 tsp. kosher salt',
#    '4 Tbsp. extra-virgin olive oil, divided',
#    '2 Tbsp. salmon roe (optional)'],
#   'nutrition': {'cal': 104,
#    'carb': '0 g(0%)',
#    'fat': '9 g(14%)',
#    'protein': '5 g(11%)',
#    'sat_fat': '2 g(9%)',
#    'sodium': '122 mg(5%)',
#    'polyunsat_fat': '3 g',
#    'fiber': '0 g(0%)',
#    'monounsat_fat': '4 g',
#    'cholesterol': '96 mg(32%)',
#    'servings': 'per serving (24 servings)'},
#   'tags': {'meal': ['appetizer', 'hors-doeuvre'],
#    'ingredient': ['egg',
#     'tuna',
#     'anchovy',
#     'mayonnaise',
#     'lemon',
#     'capers',
#     'salmon'],
#    'tag': ['olive-oil'],
#    'occasion': ['cocktail-party',
#     'new-years-eve',
#     'christmas-eve',
#     'christmas'],
#    'cuisine': ['italian']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/chickpea-mushroom-burgers',
#   'title': 'Chickpea-Mushroom Burgers ',
#   'author': 'Chris Morocco',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 1,
#   'make_again': '100%',
#   'active_time': '35 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5df9439e80eb9600080480ba/6:4/w_274%2Ch_169/COOK90_VeggieBurger_RECIPE_121219_118_2.jpg',
#   'ingredients': ['1/2 cup red or black quinoa, rinsed',
#    'Kosher salt',
#    '1/2 cup extra-virgin olive oil, divided, plus more for drizzling',
#    '2 (14.5-oz.) cans chickpeas, rinsed, drained',
#    '1 tsp. garlic powder',
#    '1/2 tsp. smoked paprika',
#    '8 oz. crimini mushrooms, trimmed, cut into 1/4" pieces',
#    '1/4 cup tahini',
#    '1/4 cup white miso',
#    '1/4 cup oat flour or all-purpose flour',
#    '8 slices sharp cheddar or vegan cheese',
#    'Mayonnaise, mustard, hamburger buns, shredded iceberg lettuce, and sliced pickles (for serving; optional)'],
#   'nutrition': {'cal': 462,
#    'carb': '38 g(13%)',
#    'fat': '28 g(44%)',
#    'protein': '17 g(34%)',
#    'sat_fat': '7 g(33%)',
#    'sodium': '708 mg(29%)',
#    'polyunsat_fat': '5 g',
#    'fiber': '9 g(36%)',
#    'monounsat_fat': '14 g',
#    'cholesterol': '19 mg(6%)',
#    'servings': 'per serving (8 servings)'},
#   'tags': {'ingredient': ['chickpea',
#     'mushroom',
#     'quinoa',
#     'garlic',
#     'paprika',
#     'cheese',
#     'mayonnaise',
#     'mustard',
#     'lettuce'],
#    'tag': ['olive-oil', 'pickles', 'cook90', 'sunday-stash'],
#    'special-consideration': ['vegan', 'wheat-gluten-free', 'vegetarian'],
#    'meal': ['dinner'],
#    'occasion': ['winter'],
#    'technique': ['bake', 'freeze-chill']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/kimchi-soup-with-tofu-and-clams',
#   'title': 'Kimchi Soup With Tofu and Clams ',
#   'author': 'David Tamarkin',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': '20 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5df7c9f2e48b9c000829ffde/6:4/w_274%2Ch_169/COOK90_KimchiClams_RECIPE_IG_121119_218.jpg',
#   'ingredients': ['2 Tbsp. neutral oil (such as canola or grapeseed)',
#    '1 small onion, thinly sliced',
#    '6 garlic cloves, thinly sliced',
#    '1 lb. kimchi, juices reserved, thinly sliced',
#    '1 Tbsp. white miso',
#    '1/2 tsp. (or more) kosher salt',
#    '1 lb. littleneck clams (8–12), scrubbed',
#    '2 Tbsp. unsalted butter',
#    '1 lb. silken tofu, drained, cut into 1" pieces',
#    '2 scallions, white and light green parts only, thinly sliced'],
#   'nutrition': {'cal': 348,
#    'carb': '17 g(6%)',
#    'fat': '19 g(29%)',
#    'protein': '29 g(58%)',
#    'sat_fat': '5 g(27%)',
#    'sodium': '1171 mg(49%)',
#    'polyunsat_fat': '5 g',
#    'fiber': '5 g(21%)',
#    'monounsat_fat': '8 g',
#    'cholesterol': '49 mg(16%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'type': ['soup-stew'],
#    'ingredient': ['onion',
#     'garlic',
#     'clam',
#     'butter',
#     'tofu',
#     'green-onion-scallion'],
#    'tag': ['cook90'],
#    'meal': ['dinner', 'one-pot-meal'],
#    'cuisine': ['korean', 'asian'],
#    'special-consideration': ['quick-and-easy',
#     'wheat-gluten-free',
#     'dairy-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/roasted-cabbage-steaks-with-crispy-chickpeas-and-herby-croutons',
#   'title': 'Roasted Cabbage Steaks With Crispy Chickpeas and Herby Croutons ',
#   'author': 'Hetty McKinnon',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 3.5,
#   'reviews': 3,
#   'make_again': '100%',
#   'active_time': '20 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5df7c9f28a496c0008295fb4/6:4/w_274%2Ch_169/COOK90_CabbageSteaks_RECIPE_V1_121119_184.jpg',
#   'ingredients': ['2 medium purple or green cabbages (4–5 lb. total; second cabbage optional)',
#    '2 tsp. (or more) kosher salt, divided',
#    '1 3/4 tsp. freshly ground black pepper, divided',
#    '2 (14.5-oz.) cans chickpeas, drained, rinsed',
#    '1 tsp. ground cumin',
#    '1/2 cup plus 1 Tbsp. extra-virgin olive oil, divided; plus more for drizzling',
#    '1 1/4 tsp. ground coriander, divided',
#    '1/2 loaf sourdough bread (about 1/2 lb.)',
#    '2 garlic cloves, finely grated, divided',
#    '2 tsp. Dijon mustard, divided',
#    '2 Tbsp. finely chopped parsley, plus whole leaves for serving',
#    '1/2 cup vegan or regular mayonnaise',
#    '2 Tbsp. (or more) fresh lemon juice'],
#   'nutrition': {'cal': 920,
#    'carb': '78 g(26%)',
#    'fat': '60 g(92%)',
#    'protein': '21 g(42%)',
#    'sat_fat': '8 g(41%)',
#    'sodium': '1043 mg(43%)',
#    'polyunsat_fat': '19 g',
#    'fiber': '15 g(60%)',
#    'monounsat_fat': '29 g',
#    'cholesterol': '11 mg(4%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'ingredient': ['cabbage',
#     'chickpea',
#     'cumin',
#     'coriander',
#     'garlic',
#     'mustard',
#     'parsley',
#     'mayonnaise',
#     'lemon'],
#    'tag': ['olive-oil', 'cook90'],
#    'type': ['bread'],
#    'special-consideration': ['vegetarian', 'dairy-free'],
#    'meal': ['dinner']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/creamy-squash-risotto-with-toasted-pepitas',
#   'title': 'Creamy Squash Risotto With Toasted Pepitas ',
#   'author': 'Abra Berens',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 1,
#   'make_again': '100%',
#   'active_time': '1 hour',
#   'image_url': 'https://assets.epicurious.com/photos/5df7c9ee3b02150008fba539/6:4/w_274%2Ch_169/COOK90_AbraRisotto_HERO_IG_V1_121119_262_V1.jpg',
#   'ingredients': ['2 large butternut squash (about 4 1/2 lb. total)',
#    '1/4 cup extra-virgin olive oil',
#    '1 Tbsp. white miso',
#    '1 tsp. smoked paprika',
#    '1/2 tsp. kosher salt',
#    '1/3 cup plus 2 Tbsp. extra-virgin olive oil',
#    '1 medium onion, finely chopped',
#    '2 1/2 tsp. (or more) kosher salt, divided',
#    '2 cups arborio rice',
#    '1 cup dry white wine or hard or sweet cider',
#    '3/4 cup raw pumpkin seeds (pepitas)',
#    '2 tsp. smoked paprika',
#    '1/4 tsp. crushed red pepper flakes',
#    '2 tsp. finely grated orange zest',
#    '1/2 cup coarsely chopped dill or parsley (from about 1/2 bunch)',
#    'Orange wedges (for serving)'],
#   'nutrition': {'cal': 696,
#    'carb': '90 g(30%)',
#    'fat': '34 g(53%)',
#    'protein': '12 g(25%)',
#    'sat_fat': '5 g(26%)',
#    'sodium': '946 mg(39%)',
#    'polyunsat_fat': '6 g',
#    'fiber': '9 g(34%)',
#    'monounsat_fat': '21 g',
#    'cholesterol': '',
#    'servings': 'per serving (6 servings)'},
#   'tags': {'type': ['risotto'],
#    'ingredient': ['squash',
#     'butternut-squash',
#     'paprika',
#     'onion',
#     'rice',
#     'wine',
#     'orange',
#     'dill',
#     'parsley'],
#    'special-consideration': ['vegan',
#     'vegetarian',
#     'dairy-free',
#     'wheat-gluten-free'],
#    'tag': ['olive-oil', 'cook90'],
#    'meal': ['dinner']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/winter-salad-hummus-bowls',
#   'title': 'Winter Salad Hummus Bowls ',
#   'author': 'Anna Stockwell',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': '30 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5df7bb4b8a496c0008295fb2/6:4/w_274%2Ch_169/COOK90_SaladPowerSprinkle_RECIPE_120519_13778.jpg',
#   'ingredients': ['4–6 large eggs',
#    '5 Tbsp. unseasoned rice vinegar',
#    '1 Tbsp. honey',
#    '1 Tbsp. tamari or soy sauce',
#    '1/2 tsp. kosher salt',
#    '1/4 cup extra-virgin olive oil, plus more for drizzling',
#    '1 bunch curly kale, stems removed, torn into bite-size pieces',
#    '1 lb. brussels sprouts, trimmed, thinly sliced',
#    '1 cup store-bought or homemade hummus',
#    '1 cup Seedy Power Sprinkle',
#    'Flaky sea salt'],
#   'nutrition': {'cal': 606,
#    'carb': '82 g(27%)',
#    'fat': '26 g(39%)',
#    'protein': '17 g(34%)',
#    'sat_fat': '5 g(23%)',
#    'sodium': '881 mg(37%)',
#    'polyunsat_fat': '4 g',
#    'fiber': '9 g(34%)',
#    'monounsat_fat': '15 g',
#    'cholesterol': '233 mg(78%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'type': ['salad', 'hummus'],
#    'ingredient': ['egg',
#     'vinegar',
#     'honey',
#     'soy-sauce',
#     'kale',
#     'brussels-sprout',
#     'seed'],
#    'tag': ['olive-oil', 'cook90'],
#    'special-consideration': ['vegetarian',
#     'wheat-gluten-free',
#     'dairy-free',
#     'healthy'],
#    'meal': ['lunch', 'dinner']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/seedy-power-sprinkle',
#   'title': 'Seedy Power Sprinkle ',
#   'author': 'Anna Stockwell',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 3.5,
#   'reviews': 2,
#   'make_again': '100%',
#   'active_time': '15 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5df7bb4be48b9c000829ffda/6:4/w_274%2Ch_169/COOK90_PowerSprinkle_RECIPE_120519_13764.jpg',
#   'ingredients': ['1 large egg white',
#    '2 Tbsp. extra-virgin olive oil',
#    '2 Tbsp. honey',
#    '1 Tbsp. Aleppo-style pepper (optional)',
#    '2 tsp. kosher salt',
#    '1 cup sunflower seeds',
#    '1/2 cup chia seeds',
#    '1/2 cup flaxseeds',
#    '1/2 cup raw sesame seeds'],
#   'nutrition': {'cal': 258,
#    'carb': '17 g(6%)',
#    'fat': '20 g(30%)',
#    'protein': '8 g(15%)',
#    'sat_fat': '2 g(11%)',
#    'sodium': '121 mg(5%)',
#    'polyunsat_fat': '10 g',
#    'fiber': '9 g(37%)',
#    'monounsat_fat': '6 g',
#    'cholesterol': '',
#    'servings': 'per serving (8 servings)'},
#   'tags': {'ingredient': ['seed', 'egg', 'honey', 'pepper', 'sesame'],
#    'tag': ['olive-oil', 'cook90'],
#    'special-consideration': ['wheat-gluten-free', 'dairy-free'],
#    'meal': ['breakfast', 'lunch', 'dinner']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/salad-pasta',
#   'title': 'Salad Pasta ',
#   'author': 'Anna Stockwell',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 3.5,
#   'reviews': 2,
#   'make_again': '100%',
#   'active_time': '20 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5df7bb498f7e840009fee0f8/6:4/w_274%2Ch_169/COOK90_ChickpeaSaladPasta_HERO_120519_13733.jpg',
#   'ingredients': ['1 (2.2-oz.) can oil-packed anchovy fillets',
#    '1 head of garlic, cloves separated, thinly sliced',
#    '3/4 cup extra-virgin olive oil',
#    '3/4 tsp. crushed red pepper flakes',
#    '1 lb. penne pasta',
#    'Kosher salt',
#    '3 Tbsp. cold unsalted butter',
#    '3 Tbsp. fresh lemon juice',
#    '1 head of radicchio, trimmed, quartered, leaves separated',
#    '1 (5-oz.) package baby arugula',
#    '1 cup basil leaves, torn if large',
#    'Freshly ground black pepper'],
#   'nutrition': {'cal': 928,
#    'carb': '93 g(31%)',
#    'fat': '53 g(81%)',
#    'protein': '22 g(44%)',
#    'sat_fat': '12 g(59%)',
#    'sodium': '641 mg(27%)',
#    'polyunsat_fat': '6 g',
#    'fiber': '5 g(20%)',
#    'monounsat_fat': '33 g',
#    'cholesterol': '36 mg(12%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'ingredient': ['pasta',
#     'anchovy',
#     'garlic',
#     'butter',
#     'lemon-juice',
#     'radicchio',
#     'arugula',
#     'basil'],
#    'type': ['salad'],
#    'tag': ['olive-oil', 'cook90', 'quick-and-healthy'],
#    'meal': ['dinner'],
#    'special-consideration': ['wheat-gluten-free', 'quick-and-easy']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/martini-on-the-rocks-easy-cocktail-retro-gin-vodka',
#   'title': 'Martini-on-the-Rocks ',
#   'author': 'Robert Simonson',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5df3d3278a496c0008295faa/6:4/w_274%2Ch_169/Martini%20Cocktail_Martini-on-the-Rocks.jpg',
#   'ingredients': ['2 1⁄4 ounces gin or vodka',
#    '3⁄4 ounce dry vermouth',
#    'Olives'],
#   'nutrition': {'cal': None,
#    'carb': None,
#    'fat': None,
#    'protein': None,
#    'sat_fat': None,
#    'sodium': None,
#    'polyunsat_fat': None,
#    'fiber': None,
#    'monounsat_fat': None,
#    'cholesterol': None,
#    'servings': None},
#   'tags': {'type': ['martini', 'cocktail'],
#    'occasion': ['cocktail-party'],
#    'ingredient': ['gin', 'vodka', 'vermouth', 'olive']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/oystertini-oyster-martini-cocktail',
#   'title': 'Oystertini ',
#   'author': 'Rowan Jacobsen',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5defc7d3ec8c940009459d66/6:4/w_274%2Ch_169/OysterMartini_RECIPE_120519_13926.jpg',
#   'ingredients': ['2 ounces (60 ml) gin',
#    '1 raw oyster, liquor reserved',
#    '1 strip of lemon peel'],
#   'nutrition': {'cal': 95,
#    'carb': '1 g(0%)',
#    'fat': '1 g(1%)',
#    'protein': '2 g(5%)',
#    'sat_fat': '0 g(1%)',
#    'sodium': '27 mg(1%)',
#    'polyunsat_fat': '0 g',
#    'fiber': '0 g(0%)',
#    'monounsat_fat': '0 g',
#    'cholesterol': '13 mg(4%)',
#    'servings': 'per serving (2 servings)'},
#   'tags': {'type': ['martini', 'cocktail'],
#    'ingredient': ['oyster', 'gin', 'lemon'],
#    'occasion': ['cocktail-party']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/puritan-cocktail-martini-variation-chartreuse',
#   'title': 'Puritan Cocktail ',
#   'author': 'Robert Simonson',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5defdf1a0bb0a80008b6387d/6:4/w_274%2Ch_169/Martini%20Cocktail_Puritan%20Cocktail.jpg',
#   'ingredients': ['2 ounces Plymouth gin',
#    '1 ounce Dolin dry vermouth',
#    '2 teaspoons yellow Chartreuse',
#    '1 dash orange bitters',
#    'Lemon twist'],
#   'nutrition': {'cal': None,
#    'carb': None,
#    'fat': None,
#    'protein': None,
#    'sat_fat': None,
#    'sodium': None,
#    'polyunsat_fat': None,
#    'fiber': None,
#    'monounsat_fat': None,
#    'cholesterol': None,
#    'servings': None},
#   'tags': {'type': ['martini'], 'ingredient': ['gin', 'lemon', 'vermouth']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/tuxedo-no-2-martini-cocktail-variation-absinthe',
#   'title': 'Tuxedo No. 2 ',
#   'author': 'Robert Simonson',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5df29bc53b02150008fba533/6:4/w_274%2Ch_169/Martini-Cocktail_Tuxedo-No.-2-recipe-121219.jpg',
#   'ingredients': ['Absinthe rinse',
#    '2 1⁄4 ounces Plymouth gin',
#    '1⁄2 ounce Dolin dry vermouth',
#    '1⁄4 ounce maraschino liqueur',
#    '4 dashes orange bitters',
#    'Orange twist and cherry'],
#   'nutrition': {'cal': None,
#    'carb': None,
#    'fat': None,
#    'protein': None,
#    'sat_fat': None,
#    'sodium': None,
#    'polyunsat_fat': None,
#    'fiber': None,
#    'monounsat_fat': None,
#    'cholesterol': None,
#    'servings': None},
#   'tags': {'type': ['martini', 'cocktail'],
#    'occasion': ['cocktail-party'],
#    'ingredient': ['gin']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/obituary-cocktail-martini-riff-drink',
#   'title': 'Obituary Cocktail ',
#   'author': 'Robert Simonson',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5df015bbf49780000871dd44/6:4/w_274%2Ch_169/3-Ingredient%20Cocktails_Obituary%20Cocktail.jpg',
#   'ingredients': ['2 ounces gin', '¼ ounce dry vermouth', '¼ ounce absinthe'],
#   'nutrition': {'cal': 86,
#    'carb': '0 g(0%)',
#    'fat': None,
#    'protein': '0 g(0%)',
#    'sat_fat': None,
#    'sodium': '1 mg(0%)',
#    'polyunsat_fat': '',
#    'fiber': None,
#    'monounsat_fat': '',
#    'cholesterol': '',
#    'servings': 'per serving (2 servings)'},
#   'tags': {'type': ['martini', 'cocktail'],
#    'ingredient': ['gin', 'vermouth', 'lemon']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/classic-dry-martini-237574',
#   'title': 'Classic Dry Martini ',
#   'author': 'The Editors of Epicurious',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 25,
#   'make_again': '85%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5defc7d20bb0a80008b63876/6:4/w_274%2Ch_169/ClassicMartini_RECIPE_120519_13893.jpg',
#   'ingredients': ['Cracked ice',
#    '2 1/2 ounces London dry gin, such as Beefeater',
#    '1/2 ounce dry vermouth, preferably Noilly Prat',
#    'Green olive for garnish'],
#   'nutrition': {'cal': None,
#    'carb': None,
#    'fat': None,
#    'protein': None,
#    'sat_fat': None,
#    'sodium': None,
#    'polyunsat_fat': None,
#    'fiber': None,
#    'monounsat_fat': None,
#    'cholesterol': None,
#    'servings': None},
#   'tags': {'ingredient': ['gin'],
#    'type': ['alcoholic', 'cocktail', 'martini'],
#    'occasion': ['christmas', 'cocktail-party'],
#    'meal': ['drink']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/chilaquiles-with-bacon-eggs-and-cheese',
#   'title': 'Chilaquiles With Bacon, Eggs, and Cheese ',
#   'author': 'Anna Stockwell',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 2,
#   'make_again': '100%',
#   'active_time': '20 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5defdb8958b8fe0009567d5a/6:4/w_274%2Ch_169/Chilaquiles_HERO_V2_120519_13686.jpg',
#   'ingredients': ['1/2 lb. thick-cut bacon, cut into small pieces',
#    '6 garlic cloves, crushed, peeled',
#    '1 serrano chile, thinly sliced',
#    '1 (14.5-oz.) can pinto beans, drained, rinsed',
#    '2 cups jarred or homemade salsa verde, plus more for serving',
#    '8 cups thick tortilla chips, plus more',
#    'Kosher salt',
#    '4 oz. Monterey Jack or pepper Jack, shredded (about 1 cup)',
#    '1/2 oz. Cotija or Parmesan, finely grated (about 1/4 cup)',
#    '8 large eggs',
#    '1/4 cup cilantro leaves with tender stems',
#    'Hot sauce and lime wedges (for serving)'],
#   'nutrition': {'cal': 875,
#    'carb': '73 g(24%)',
#    'fat': '51 g(78%)',
#    'protein': '32 g(63%)',
#    'sat_fat': '16 g(79%)',
#    'sodium': '1063 mg(44%)',
#    'polyunsat_fat': '12 g',
#    'fiber': '8 g(34%)',
#    'monounsat_fat': '19 g',
#    'cholesterol': '305 mg(102%)',
#    'servings': 'per serving (6 servings)'},
#   'tags': {'meal': ['breakfast', 'one-pot-meal'],
#    'ingredient': ['bacon',
#     'garlic',
#     'bean',
#     'cheese',
#     'egg',
#     'cilantro',
#     'lime'],
#    'location': ['chile'],
#    'type': ['salsa'],
#    'occasion': ['winter', 'christmas', 'new-years-day'],
#    'special-consideration': ['wheat-gluten-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/instant-pot-tequila-lime-carnitas',
#   'title': 'Instant Pot Tequila Lime Carnitas ',
#   'author': 'Jen Fisch',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': '15 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5deac79b5bd6fe000873331b/6:4/w_274%2Ch_169/Tequila-Lime-Carnitas_KETO.jpg',
#   'ingredients': ['2 1/2- to 3-pound boneless pork butt roast, cut into 3 or 4 large pieces',
#    '2 tablespoons chile-lime seasoning (like Tajín)',
#    '1/2 cup chicken or beef broth',
#    '1/4 cup 100% agave tequila',
#    '4 tablespoons fresh lime juice, divided',
#    '2 tablespoons avocado oil',
#    'Fine Himalayan pink salt',
#    '1/2 cup chopped fresh cilantro',
#    '1 teaspoon grated lime zest',
#    '2 small heads butter lettuce',
#    'Toppings, such as queso fresco, avocado, sour cream, and/or hot sauce'],
#   'nutrition': {'cal': 697,
#    'carb': '5 g(2%)',
#    'fat': '46 g(71%)',
#    'protein': '56 g(112%)',
#    'sat_fat': '14 g(72%)',
#    'sodium': '1032 mg(43%)',
#    'polyunsat_fat': '6 g',
#    'fiber': '1 g(4%)',
#    'monounsat_fat': '21 g',
#    'cholesterol': '193 mg(64%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'source': ['harpercollins'],
#    'ingredient': ['pork', 'lime-juice', 'cilantro', 'lime', 'lettuce'],
#    'special-consideration': ['wheat-gluten-free',
#     'soy-free',
#     'tree-nut-free',
#     'peanut-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/instant-pot-chicken-parmesan-meatballs',
#   'title': 'Instant Pot Chicken Parmesan Meatballs ',
#   'author': 'Jen Fisch',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': '15 minutes',
#   'image_url': 'https://assets.epicurious.com/photos/5deac5dfc74c31000809f0b7/6:4/w_274%2Ch_169/Chicken-Parmesan-Meatballs_KETO.jpg',
#   'ingredients': ['1 large egg',
#    '2 cups shredded mozzarella cheese (8 ounces)',
#    '1/2 cup grated Parmesan cheese (2 ounces)',
#    '1/2 cup crushed pork rinds or almond meal',
#    '2 tablespoons chopped fresh basil, plus 1/4 cup thinly sliced fresh basil for garnish',
#    '2 cloves garlic, minced',
#    '1 1/2 pounds ground chicken',
#    '4 tablespoons olive oil, divided',
#    '1 tablespoon tomato paste',
#    '1 (14.5-ounce) can whole peeled plum (Italian) tomatoes, undrained',
#    '1 teaspoon dried basil, crushed',
#    '1 teaspoon garlic powder'],
#   'nutrition': {'cal': 714,
#    'carb': '8 g(3%)',
#    'fat': '53 g(82%)',
#    'protein': '52 g(105%)',
#    'sat_fat': '18 g(89%)',
#    'sodium': '805 mg(34%)',
#    'polyunsat_fat': '5 g',
#    'fiber': '3 g(11%)',
#    'monounsat_fat': '22 g',
#    'cholesterol': '253 mg(84%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'source': ['harpercollins'],
#    'meal': ['appetizer'],
#    'ingredient': ['chicken',
#     'poultry',
#     'mozzarella',
#     'parmesan',
#     'tomato',
#     'basil',
#     'garlic'],
#    'special-consideration': ['soy-free',
#     'peanut-free',
#     'tree-nut-free',
#     'wheat-gluten-free',
#     'high-protein'],
#    'type': ['meatball'],
#    'cuisine': ['italian-american']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/spicy-chickpea-poppers',
#   'title': 'Spicy Chickpea Poppers ',
#   'author': 'Mandy Lee',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5df01cf34adda900082c6ffc/6:4/w_274%2Ch_169/Spicy-chickpea-poppers-recipe-HC-121019.jpg',
#   'ingredients': ['2 1/2 heads of garlic (about 35 cloves)',
#    '3 fresh bay leaves',
#    '1/2 cup (120 mL) canola oil',
#    '1 tablespoon fish sauce',
#    '1/4 teaspoon ground white pepper',
#    '2 teaspoons ground Sichuan peppercorns',
#    '2 teaspoons chile flakes',
#    '1/2 teaspoon ground white pepper',
#    '1/2 teaspoon ground coriander',
#    '1/2 teaspoon ground kombu',
#    '1/4 teaspoon ground cumin',
#    '1/4 teaspoon five-spice powder',
#    '1/4 teaspoon light brown sugar',
#    '1/4 teaspoon sea salt, plus more as needed',
#    'Canola oil, for frying',
#    '1 (15-ounce/425 g) can chickpeas, drained and peeled',
#    '1 1/2 tablespoons buttermilk',
#    '1 tablespoon plus 1/4 cup (31 g) all-purpose flour',
#    '2 teaspoons garlic powder',
#    '1/2 teaspoon baking soda',
#    '1/2 teaspoon ground white pepper',
#    '1/4 teaspoon fine sea salt',
#    'A good handful fresh Thai basil leaves',
#    '1 garlic clove, grated',
#    '2 teaspoons Garlic Confit Sauce (see below)'],
#   'nutrition': {'cal': 480,
#    'carb': '47 g(16%)',
#    'fat': '29 g(45%)',
#    'protein': '12 g(24%)',
#    'sat_fat': '2 g(11%)',
#    'sodium': '792 mg(33%)',
#    'polyunsat_fat': '8 g',
#    'fiber': '9 g(36%)',
#    'monounsat_fat': '17 g',
#    'cholesterol': '0 mg(0%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'source': ['harpercollins'],
#    'ingredient': ['chickpea',
#     'chile-pepper',
#     'coriander',
#     'buttermilk',
#     'garlic',
#     'basil'],
#    'special-consideration': ['vegetarian',
#     'soy-free',
#     'tree-nut-free',
#     'peanut-free'],
#    'meal': ['appetizer']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/pandoras-box-shibuya-honey-toast',
#   'title': 'Pandora’s Box ',
#   'author': 'Mandy Lee',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5de989c5c74c31000809f0ac/6:4/w_274%2Ch_169/Escapism_pandorasbox02.jpg',
#   'ingredients': ['1 vanilla bean',
#    '2 cups (480 mL) whole milk',
#    '1 tablespoon loose chamomile tea',
#    '5 large egg yolks',
#    '1/4 cup (60 mL) honey',
#    '1/4 cup (50 g) granulated sugar',
#    '5 tablespoons (39 g) all-purpose flour',
#    '1 tablespoon custard powder (find online, or replace with another 1 tablespoon flour)',
#    '4 tablespoons (1/2 stick/54 g) unsalted butter',
#    '1 approximately 11-inch (28-cm) loaf Hokkaido milk bread or rectangular brioche',
#    '3/4 cup (180 mL) whole milk',
#    '1 large egg',
#    '2 tablespoons light brown sugar',
#    '1/8 teaspoon ground cinnamon',
#    '1/8 teaspoon salt',
#    'Granulated sugar, for coating',
#    'Unsalted butter, for frying',
#    'Tart berries—raspberries, strawberries, blueberries—to sprinkle on top'],
#   'nutrition': {'cal': 2480,
#    'carb': '230 g(77%)',
#    'fat': '155 g(238%)',
#    'protein': '47 g(94%)',
#    'sat_fat': '88 g(441%)',
#    'sodium': '1281 mg(53%)',
#    'polyunsat_fat': '10 g',
#    'fiber': '6 g(25%)',
#    'monounsat_fat': '44 g',
#    'cholesterol': '1016 mg(339%)',
#    'servings': 'per serving (2 servings)'},
#   'tags': {'source': ['harpercollins'],
#    'meal': ['dessert'],
#    'occasion': ['christmas', 'new-years-eve', 'entertaining'],
#    'type': ['custard'],
#    'ingredient': ['milk-cream', 'egg', 'cinnamon', 'butter'],
#    'special-consideration': ['soy-free', 'peanut-free', 'tree-nut-free'],
#    'cuisine': ['japanese']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/islay-and-olive-batched-dirty-martini-cocktail',
#   'title': 'Islay and Olive ',
#   'author': 'Maggie Hoffman',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 1.0,
#   'reviews': 1,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5deea959a267450008a7b89d/6:4/w_274%2Ch_169/Batch%20Cocktails_Islay%20and%20Olive.jpg',
#   'ingredients': ['8 pitted green olives',
#    '1 ½ cups vodka',
#    '1 cup plus 2 tablespoons Islay Scotch (such as Laphroaig 10)',
#    '¾ cup dry vermouth (such as Dolin)',
#    '½ cup water',
#    '2 tablespoons olive brine',
#    '10 dashes orange bitters',
#    'Pinch fine sea salt',
#    '1 ½ teaspoons olive oil',
#    '12 lemon twists',
#    '12 to 24 green olives (optionally frozen)'],
#   'nutrition': {'cal': 146,
#    'carb': '3 g(1%)',
#    'fat': '2 g(3%)',
#    'protein': '0 g(1%)',
#    'sat_fat': '0 g(1%)',
#    'sodium': '128 mg(5%)',
#    'polyunsat_fat': '0 g',
#    'fiber': '2 g(6%)',
#    'monounsat_fat': '1 g',
#    'cholesterol': '',
#    'servings': 'per serving (12 servings)'},
#   'tags': {'type': ['cocktail', 'alcoholic'],
#    'occasion': ['cocktail-party'],
#    'ingredient': ['olive',
#     'vodka',
#     'lemon',
#     'vermouth',
#     'whiskey',
#     'scotch']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/sneaky-peat-cranberry-scotch-big-batch-cocktail',
#   'title': 'Sneaky Peat ',
#   'author': 'Maggie Hoffman',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 3.0,
#   'reviews': 3,
#   'make_again': '100%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5deeac02cea30b00092ede51/6:4/w_274%2Ch_169/Batch%20Cocktails_Sneaky%20Peat.jpg',
#   'ingredients': ['2 1/4 cups Scotch (such as Dewar’s White Label)',
#    '2 1/2 tablespoons Angostura bitters',
#    '2 cups chilled extra-strong oolong',
#    '1 cup plus 2 tablespoons chilled cranberry syrup',
#    '1/2 cup water',
#    '3/4 cup fresh lemon juice',
#    '2 cups water',
#    '6 oolong tea bags',
#    '1 cup water',
#    '1 cup sugar',
#    '1/2 cup fresh or frozen cranberries',
#    '1 tablespoon Scotch (optional)',
#    '1/2 cup fresh or frozen cranberries',
#    '8 lemon wheels'],
#   'nutrition': {'cal': 260,
#    'carb': '42 g(14%)',
#    'fat': '0 g(0%)',
#    'protein': '1 g(1%)',
#    'sat_fat': '0 g(0%)',
#    'sodium': '8 mg(0%)',
#    'polyunsat_fat': '0 g',
#    'fiber': '1 g(5%)',
#    'monounsat_fat': '0 g',
#    'cholesterol': '',
#    'servings': 'per serving (12 servings)'},
#   'tags': {'type': ['cocktail'],
#    'occasion': ['cocktail-party', 'christmas', 'winter'],
#    'ingredient': ['lemon-juice',
#     'cranberry',
#     'scotch',
#     'lemon',
#     'tea',
#     'whiskey']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/pansit-palabok-rice-noodles-with-shrimp-sauce-pancit-filipino-dish',
#   'title': 'Pansit Palabok (Rice Noodles with Shrimp Sauce) ',
#   'author': 'Nicole Ponseca',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dead3f2e48b9c000829ffae/6:4/w_274%2Ch_169/Pansit-Palabok_I-AM-A-FILIPINO.jpg',
#   'ingredients': ['½ cup (1 stick/115 g) unsalted butter',
#    '¾ cup (95 g) all-purpose flour',
#    '2 to 3 cups (480 to 720 ml) warm shrimp stock (recipe follows)',
#    'Fish sauce',
#    '2 tablespoons vegetable oil',
#    '1 tablespoon minced garlic',
#    '1 pound (455 g) raw jumbo shrimp, shells removed and reserved, shrimp halved lengthwise and deveined',
#    '1 pound (455 g) squid bodies, cut into thick rings',
#    '1 pound (455 g) palabok noodles (or rice noodles), cooked, drained, and kept warm',
#    '¼ cup (25 g) crushed pork rinds',
#    '1 cup (300 g) diced smoked tofu',
#    '¼ cup (2.5 g) tinapa or bonito flakes',
#    '1 lemon, cut into quarters',
#    '2 tablespoons vegetable oil',
#    '1 large white onion, sliced',
#    '2 tablespoons minced garlic',
#    'Shrimp shells from 1 pound (455 g) shrimp',
#    '½ cup (140 g) annatto seeds',
#    '4 ounces (115 g) crab paste with bean oil',
#    '3 tablespoons fresh lemon juice',
#    '1 tablespoon fish sauce',
#    '3 bay leaves',
#    '2 tablespoons whole black peppercorns'],
#   'nutrition': {'cal': 283,
#    'carb': '18 g(6%)',
#    'fat': '17 g(26%)',
#    'protein': '16 g(31%)',
#    'sat_fat': '5 g(23%)',
#    'sodium': '389 mg(16%)',
#    'polyunsat_fat': '3 g',
#    'fiber': '3 g(12%)',
#    'monounsat_fat': '8 g',
#    'cholesterol': '137 mg(46%)',
#    'servings': 'per serving (18 servings)'},
#   'tags': {'cuisine': ['asian', 'southeast-asian'],
#    'ingredient': ['noodle', 'shrimp', 'squid', 'lemon', 'egg'],
#    'type': ['sauce']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/bubble-and-squeak-with-stilton',
#   'title': 'Bubble and Squeak With Stilton ',
#   'author': 'Tom Parker Bowles',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5de987bf58b8fe0009567d46/6:4/w_274%2Ch_169/squeak.jpg',
#   'ingredients': ['3 tablespoons vegetable oil',
#    '50g (about 3 ½ tablespoons) butter',
#    '1 large onion, thinly sliced',
#    '2 leeks, sliced',
#    'About 250g (½ lb.) leftover cooked potatoes, roughly diced',
#    'About 200g (7 ounces) leftover cooked carrots, diced',
#    'About 200g (7 ounces) leftover cooked brussels sprouts, cut in half',
#    '3 teaspoons chopped parsley',
#    '125g (4.4 ounces) Stilton cheese, roughly crumbled'],
#   'nutrition': {'cal': 425,
#    'carb': '31 g(10%)',
#    'fat': '30 g(46%)',
#    'protein': '11 g(23%)',
#    'sat_fat': '13 g(65%)',
#    'sodium': '421 mg(18%)',
#    'polyunsat_fat': '3 g',
#    'fiber': '6 g(25%)',
#    'monounsat_fat': '13 g',
#    'cholesterol': '50 mg(17%)',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'source': ['harpercollins'],
#    'occasion': ['winter', 'fall'],
#    'meal': ['side'],
#    'ingredient': ['carrot', 'leek', 'potato', 'brussels-sprout', 'cheese'],
#    'special-consideration': ['soy-free',
#     'peanut-free',
#     'tree-nut-free',
#     'wheat-gluten-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/spiced-pomegranate-and-orange-glazed-ham',
#   'title': 'Spiced Pomegranate and Orange Glazed Ham ',
#   'author': 'Donna Hay',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5de983563b02150008fba517/6:4/w_274%2Ch_169/spiced-pomegranate-and-orange-glazed-ham-.jpg',
#   'ingredients': ['2 sticks cinnamon',
#    '4 star-anise',
#    '1 cup (250ml) orange juice',
#    '1 1⁄2 cups (260g) light brown sugar',
#    '1⁄4 cup (60ml) pomegranate molasses',
#    '1⁄4 cup (90g) honey',
#    '1 (13–15 lb.) ham leg',
#    '4 oranges, peeled, thinly sliced and patted dry'],
#   'nutrition': {'cal': 953,
#    'carb': '54 g(18%)',
#    'fat': '47 g(72%)',
#    'protein': '75 g(151%)',
#    'sat_fat': '16 g(78%)',
#    'sodium': '4721 mg(197%)',
#    'polyunsat_fat': '6 g',
#    'fiber': '1 g(5%)',
#    'monounsat_fat': '22 g',
#    'cholesterol': '268 mg(89%)',
#    'servings': 'per serving (14 servings)'},
#   'tags': {'source': ['harpercollins'],
#    'ingredient': ['ham', 'orange', 'pomegranate', 'honey', 'pork'],
#    'occasion': ['christmas', 'winter'],
#    'meal': ['dinner']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/christmas-fruit-cake',
#   'title': 'Christmas Cake ',
#   'author': 'Donna Hay',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5de9814bec8c940009459d59/6:4/w_274%2Ch_169/118_ChristmasCakeSlice.jpg',
#   'ingredients': ['3 cups (450g) raisins',
#    '1 1⁄2 cups (240g) golden raisins',
#    '1 cup (160g) dried currants',
#    '8 soft fresh dates (160g), pitted and chopped',
#    '1 cup (140g) slivered almonds',
#    '3/4 cup (180ml) brandy',
#    '250g unsalted butter, softened',
#    '1 1/4 cups (220g) light brown sugar',
#    '4 eggs',
#    '2 1/4 cups (335g) plain (all-purpose) flour, sifted',
#    '1/4 teaspoon bicarbonate of (baking) soda',
#    '1 1/2 teaspoons ground cinnamon',
#    '1 teaspoon ground allspice',
#    '2–3 tablespoons brandy, extra'],
#   'nutrition': {'cal': 416,
#    'carb': '64 g(21%)',
#    'fat': '15 g(23%)',
#    'protein': '6 g(12%)',
#    'sat_fat': '7 g(35%)',
#    'sodium': '22 mg(1%)',
#    'polyunsat_fat': '2 g',
#    'fiber': '4 g(15%)',
#    'monounsat_fat': '5 g',
#    'cholesterol': '59 mg(20%)',
#    'servings': 'per serving (20 servings)'},
#   'tags': {'source': ['harpercollins'],
#    'occasion': ['christmas', 'winter'],
#    'type': ['cake'],
#    'meal': ['dessert'],
#    'ingredient': ['raisin', 'currant', 'date', 'almond', 'cinnamon', 'butter'],
#    'technique': ['bake'],
#    'special-consideration': ['soy-free', 'peanut-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/overnight-porridge-congee-chao-andrea-nguyen-vietnamese-rice-soup',
#   'title': 'Super-Simple Overnight Porridge ',
#   'author': 'Andrea Nguyen',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 2,
#   'make_again': '100%',
#   'active_time': '30 minutes, plus overnight soaking',
#   'image_url': 'https://assets.epicurious.com/photos/5de9709fec8c940009459d54/6:4/w_274%2Ch_169/Overnight%20Rice%20Porridge.jpg',
#   'ingredients': ['2 cups packed cooked white rice',
#    'About 5 cups chicken stock, vegetable stock, or store-bought chicken or vegetable broth',
#    '2 cups water, plus more as needed',
#    '3 thick slices unpeeled ginger, bruised',
#    '2 green onions, white parts kept whole, green parts cut into thin rings',
#    'About ½ teaspoon fine sea salt',
#    'Recently ground black pepper (optional)'],
#   'nutrition': {'cal': 127,
#    'carb': '28 g(9%)',
#    'fat': '0 g(1%)',
#    'protein': '2 g(5%)',
#    'sat_fat': '0 g(0%)',
#    'sodium': '342 mg(14%)',
#    'polyunsat_fat': '0 g',
#    'fiber': '1 g(3%)',
#    'monounsat_fat': '0 g',
#    'cholesterol': '',
#    'servings': 'per serving (4 servings)'},
#   'tags': {'ingredient': ['rice', 'ginger', 'green-onion-scallion'],
#    'cuisine': ['vietnamese'],
#    'type': ['soup-stew'],
#    'special-consideration': ['healthy'],
#    'meal': ['breakfast', 'lunch']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/sourdough-rye-brownies',
#   'title': 'Sourdough Rye Brownies ',
#   'author': 'Michelle Eshkeri',
#   'date': 'December 2019',
#   'month': 'December',
#   'year': 2019,
#   'rating': 3.0,
#   'reviews': 7,
#   'make_again': '57%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5de7f310f49780000871dd1b/6:4/w_274%2Ch_169/sourdough-rye-brownies-recipe-120319.jpg',
#   'ingredients': ['72g (2¾ oz) wholegrain rye flour',
#    '57g (2¼ oz) water',
#    '36g (1½ oz) rye or wheat starter (8–12 hours after last refreshment)',
#    '194g (6¾ oz) wholegrain rye flour',
#    '250g (9 oz)/5 whole eggs,beaten',
#    '100g (3½ oz) sugar',
#    '195g (6¾ oz) unsalted butter',
#    '475g (1lb ½ oz) dark chocolate, at least 66% cocoa solids',
#    '77g (3 oz) sugar',
#    '265g (9¼ oz) dark brown sugar',
# ...
#  {'url': 'https://www.epicurious.com/recipes/food/views/chocolate-pudding-pie',
#   'title': 'Chocolate Pudding Pie ',
#   'author': 'Chris Morocco',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 2.5,
#   'reviews': 3,
#   'make_again': '67%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5ddbef653801e50009d8713e/6:4/w_274%2Ch_169/Chocolate_pudding_pie_recipe_BA_112519.jpg',
#   'ingredients': ['1 Blind-Baked Pie Crust',
#    '½ cup sugar',
#    '3 Tbsp. unsweetened cocoa powder, preferably Dutch-process',
#    '2 Tbsp. cornstarch',
#    '2 large eggs',
#    '2 large egg yolks',
#    '2½ cups whole milk',
#    '1 tsp. vanilla extract',
#    '½ tsp. kosher salt',
#    '4 oz. bittersweet chocolate, chopped',
#    '1 tsp. unflavored powdered gelatin',
#    '2 cups heavy cream',
#    '2 Tbsp. sugar',
#    '2 tsp. vanilla extract',
#    '1 tsp. kosher salt'],
#   'nutrition': {'cal': 557,
#    'carb': '48 g(16%)',
#    'fat': '39 g(59%)',
#    'protein': '8 g(16%)',
#    'sat_fat': '21 g(107%)',
#    'sodium': '504 mg(21%)',
#    'polyunsat_fat': '2 g',
#    'fiber': '2 g(8%)',
#    'monounsat_fat': '12 g',
#    'cholesterol': '182 mg(61%)',
#    'servings': 'per serving (8 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'meal': ['dessert'],
#    'type': ['pie', 'custard'],
#    'ingredient': ['chocolate', 'egg', 'milk-cream'],
#    'special-consideration': ['vegetarian',
#     'soy-free',
#     'tree-nut-free',
#     'peanut-free'],
#    'technique': ['chill']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/blind-baked-pie-crust',
#   'title': 'Blind-Baked Pie Crust ',
#   'author': 'Chris Morocco',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 2,
#   'make_again': '100%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd719563d03ba000822a07f/6:4/w_274%2Ch_169/Blind_baked_pie_crust_recipe_BA_111819.jpg',
#   'ingredients': ['2 Tbsp. granulated sugar',
#    '2 tsp. Diamond Crystal or 1 tsp. Morton kosher salt',
#    '2⅔ cups all-purpose flour, plus more for dusting',
#    '1½ cups (3 sticks) chilled unsalted butter, cut into ½" pieces'],
#   'nutrition': {'cal': 1876,
#    'carb': '140 g(47%)',
#    'fat': '140 g(215%)',
#    'protein': '19 g(37%)',
#    'sat_fat': '88 g(439%)',
#    'sodium': '813 mg(34%)',
#    'polyunsat_fat': '6 g',
#    'fiber': '5 g(18%)',
#    'monounsat_fat': '36 g',
#    'cholesterol': '366 mg(122%)',
#    'servings': 'per serving (2 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'meal': ['dessert'],
#    'type': ['pie'],
#    'technique': ['bake'],
#    'ingredient': ['butter'],
#    'special-consideration': ['vegetarian',
#     'soy-free',
#     'tree-nut-free',
#     'peanut-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/banana-cream-pie',
#   'title': 'Banana Cream Pie ',
#   'author': 'Chris Morocco',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 1,
#   'make_again': '100%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd3082002f76c00099dfb9b/6:4/w_274%2Ch_169/Banana_cream_pie_recipe_BA_111819.jpg',
#   'ingredients': ['9 whole graham crackers',
#    '¼ cup salted dry-roasted peanuts',
#    '½ tsp. kosher salt',
#    '6 Tbsp. unsalted butter, melted',
#    '½ cup granulated sugar',
#    '¼ cup cornstarch',
#    '2 large eggs',
#    '3 large egg yolks',
#    '3 cups whole milk',
#    '2 tsp. vanilla extract',
#    '½ tsp. kosher salt, plus more',
#    '2 Tbsp. chilled unsalted butter',
#    '4 large ripe but firm bananas, sliced ¼" thick',
#    '2 cups heavy cream',
#    '¼ cup powdered sugar',
#    '¼ cup chopped salted dry-roasted peanuts'],
#   'nutrition': {'cal': 653,
#    'carb': '53 g(18%)',
#    'fat': '46 g(70%)',
#    'protein': '11 g(22%)',
#    'sat_fat': '25 g(123%)',
#    'sodium': '395 mg(16%)',
#    'polyunsat_fat': '4 g',
#    'fiber': '3 g(11%)',
#    'monounsat_fat': '14 g',
#    'cholesterol': '237 mg(79%)',
#    'servings': 'per serving (8 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'occasion': ['thanksgiving', 'winter'],
#    'meal': ['dessert'],
#    'type': ['pie', 'custard'],
#    'ingredient': ['banana', 'egg', 'milk-cream', 'peanut'],
#    'special-consideration': ['soy-free', 'vegetarian']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/why-is-it-so-good-gravy',
#   'title': 'Why-Is-It-So-Good Gravy ',
#   'author': 'Molly Baz',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 2,
#   'make_again': '100%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd306f9ede8290009cece37/6:4/w_274%2Ch_169/Why_is_it_so_good_gravy_recipe_BA_111818.jpg',
#   'ingredients': ['3 lb. turkey and/or chicken wings, flats and drumettes separated',
#    '4 Tbsp. extra-virgin olive oil, divided',
#    '2 heads of garlic, cut in half crosswise',
#    '2 large shallots, unpeeled, halved',
#    '1 (4-inch) piece ginger, scrubbed, thickly sliced',
#    '4 oz. crimini, shiitake, or white button mushrooms, torn into large pieces',
#    '2 tsp. black peppercorns, lightly crushed',
#    '6 Tbsp. all-purpose flour',
#    '4 Tbsp. unsalted butter, room temperature',
#    '½ cup amontillado sherry',
#    '6 cups turkey stock or low-sodium chicken broth, warmed',
#    '2 tsp. sherry vinegar or red wine vinegar',
#    '1 tsp. MSG',
#    'Kosher salt, freshly ground pepper (optional)'],
#   'nutrition': {'cal': 460,
#    'carb': '17 g(6%)',
#    'fat': '30 g(46%)',
#    'protein': '30 g(59%)',
#    'sat_fat': '10 g(48%)',
#    'sodium': '389 mg(16%)',
#    'polyunsat_fat': '5 g',
#    'fiber': '1 g(5%)',
#    'monounsat_fat': '14 g',
#    'cholesterol': '168 mg(56%)',
#    'servings': 'per serving (10 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'occasion': ['thanksgiving'],
#    'ingredient': ['condiment',
#     'turkey',
#     'garlic',
#     'shallot',
#     'mushroom',
#     'parsley',
#     'ginger',
#     'sherry'],
#    'type': ['sauce'],
#    'special-consideration': ['dairy-free', 'soy-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/fancy-cranberry-sauce',
#   'title': 'Fancy Cranberry Sauce ',
#   'author': 'Andy Baraghani',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 3.0,
#   'reviews': 1,
#   'make_again': '100%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd305eb83f02e0008e65b94/6:4/w_274%2Ch_169/Fancy_cranberry_sauce_recipe_BA_111819.jpg',
#   'ingredients': ['Nonstick vegetable oil spray',
#    '1 Tbsp. plus 1½ tsp. unflavored powdered gelatin',
#    '1½ lb. fresh (or frozen, thawed cranberries',
#    '4 cardamom pods, lightly crushed',
#    '3 fresh bay leaves',
#    'Pinch of kosher salt',
#    '1 cup unsweetened cranberry juice or water',
#    '1½ cups plus 3 Tbsp. sugar',
#    '2 (2x1") strips orange zest, very thinly sliced lengthwise'],
#   'nutrition': {'cal': 194,
#    'carb': '45 g(15%)',
#    'fat': '2 g(3%)',
#    'protein': '1 g(3%)',
#    'sat_fat': '0 g(1%)',
#    'sodium': '16 mg(1%)',
#    'polyunsat_fat': '0 g',
#    'fiber': '3 g(13%)',
#    'monounsat_fat': '1 g',
#    'cholesterol': '',
#    'servings': 'per serving (10 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'occasion': ['thanksgiving', 'fall'],
#    'type': ['cranberry-sauce', 'condiment-spread'],
#    'ingredient': ['cranberry', 'cardamom', 'condiment'],
#    'meal': ['side'],
#    'special-consideration': ['dairy-free',
#     'peanut-free',
#     'tree-nut-free',
#     'soy-free',
#     'wheat-gluten-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/squash-and-radicchio-salad-with-pecans',
#   'title': 'Squash and Radicchio Salad With Pecans ',
#   'author': 'Christina Chaey',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 4.0,
#   'reviews': 3,
#   'make_again': '100%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd304f4f3dc4c00088a00cc/6:4/w_274%2Ch_169/Squash_and_radicchio_salad_with_pecans_recipe_BA_111819.jpg',
#   'ingredients': ['6 898, honeynut, or delicata squash, halved, seeds removed, sliced into 1"-thick half-moons',
#    '¼ cup extra-virgin olive oil',
#    'Kosher salt, freshly ground pepper',
#    '1 cup pecans',
#    '1 tsp. plus ½ cup extra-virgin olive oil; plus more for drizzling',
#    'Kosher salt',
#    '½ small shallot, finely chopped',
#    '¼ cup fresh lemon juice',
#    '2 Tbsp. fresh orange juice',
#    '2 Tbsp. Dijon mustard',
#    '4 tsp. pure maple syrup',
#    'Freshly ground black pepper',
#    '2 small heads of radicchio, leaves separated, torn if large',
#    '½ medium Asian pear, thinly sliced',
#    '1 Tbsp. fresh lemon juice',
#    '3 oz. Piave cheese or Parmesan, shaved',
#    '¼ cup parsley leaves',
#    '½ lemon'],
#   'nutrition': {'cal': None,
#    'carb': None,
#    'fat': None,
#    'protein': None,
#    'sat_fat': None,
#    'sodium': None,
#    'polyunsat_fat': None,
#    'fiber': None,
#    'monounsat_fat': None,
#    'cholesterol': None,
#    'servings': None},
#   'tags': {'source': ['bon-appetit'],
#    'meal': ['side'],
#    'type': ['salad'],
#    'occasion': ['fall', 'thanksgiving'],
#    'ingredient': ['squash',
#     'pecan',
#     'lemon',
#     'orange',
#     'citrus',
#     'mustard',
#     'maple-syrup',
#     'radicchio',
#     'pear',
#     'asian-pear',
#     'cheese',
#     'parmesan'],
#    'special-consideration': ['vegetarian', 'wheat-gluten-free', 'soy-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/mashed-potatoes-with-crispety-cruncheties',
#   'title': 'Mashed Potatoes With Crispety Cruncheties ',
#   'author': 'Molly Baz',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 2.5,
#   'reviews': 2,
#   'make_again': '50%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd303d33b6bcb0008814282/6:4/w_274%2Ch_169/Mashed_potatoes_with_crispety_cruncheties_recipe_recipe_BA_111819.jpg',
#   'ingredients': ['4 lb. German Butterball or Yukon Gold potatoes, scrubbed',
#    '1 head of garlic, divided',
#    '5 sprigs thyme',
#    '2 tsp. black peppercorns, lightly crushed',
#    '1¼ cups (2½ sticks) unsalted butter',
#    '4 cups (or more) whole milk',
#    '1 Tbsp. (or more) kosher salt',
#    '1 lemon',
#    '2 ½"-thick slices country-style bread, torn into 1" pieces',
#    '2 cups kettle-style potato chips (such as Cape Cod)',
#    '4 Tbsp. unsalted butter',
#    'Kosher salt, freshly ground pepper',
#    '3 sprigs thyme, leaves picked',
#    '1 tsp. hot smoked Spanish paprika',
#    '⅓ cup chopped parsley'],
#   'nutrition': {'cal': 526,
#    'carb': '48 g(16%)',
#    'fat': '35 g(53%)',
#    'protein': '9 g(18%)',
#    'sat_fat': '20 g(99%)',
#    'sodium': '706 mg(29%)',
#    'polyunsat_fat': '2 g',
#    'fiber': '5 g(22%)',
#    'monounsat_fat': '10 g',
#    'cholesterol': '83 mg(28%)',
#    'servings': 'per serving (10 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'meal': ['side'],
#    'occasion': ['thanksgiving', 'fall', 'winter'],
#    'ingredient': ['potato',
#     'garlic',
#     'thyme',
#     'butter',
#     'milk-cream',
#     'lemon',
#     'parsley'],
#    'special-consideration': ['vegetarian',
#     'soy-free',
#     'tree-nut-free',
#     'peanut-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/glazed-leeks-with-pine-nut-salsa-verde',
#   'title': 'Glazed Leeks With Pine Nut Salsa Verde ',
#   'author': 'Andy Baraghani',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd302c616ca730009bb2d30/6:4/w_274%2Ch_169/Glazed_leeks_with_nut_salsa_verde.jpg',
#   'ingredients': ['6 large leeks (about 2½ lb. total), dark green parts removed',
#    'Kosher salt',
#    '1 red chile (such as Holland or Fresno), halved lengthwise',
#    '¼ cup honey',
#    '¾ cup plus 2 Tbsp. sherry vinegar or red wine vinegar',
#    '¼ cup pine nuts',
#    '½ cup finely chopped parsley',
#    '⅓ cup extra-virgin olive oil',
#    '2 Tbsp. chopped drained capers',
#    'Freshly ground black pepper'],
#   'nutrition': {'cal': 201,
#    'carb': '22 g(7%)',
#    'fat': '12 g(19%)',
#    'protein': '2 g(4%)',
#    'sat_fat': '2 g(8%)',
#    'sodium': '71 mg(3%)',
#    'polyunsat_fat': '3 g',
#    'fiber': '2 g(8%)',
#    'monounsat_fat': '7 g',
#    'cholesterol': '',
#    'servings': 'per serving (8 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'meal': ['side'],
#    'occasion': ['thanksgiving', 'fall'],
#    'ingredient': ['leek',
#     'chile-pepper',
#     'pine-nut',
#     'parsley',
#     'capers',
#     'honey'],
#    'type': ['salsa'],
#    'special-consideration': ['vegetarian',
#     'dairy-free',
#     'peanut-free',
#     'soy-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/cornbread-stuffing-with-sausage-and-corn-nuts',
#   'title': 'Cornbread Stuffing With Sausage and Corn Nuts ',
#   'author': 'Rick Martinez',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd30186932c5100093d70f4/6:4/w_274%2Ch_169/Cornbread_stuffing_with_sausage_and_corn_nuts_recipe_%20BA_111818.jpg',
#   'ingredients': ['3 lb. cornbread, cut into ¾" pieces (14–16 cups)',
#    '1½ lb. breakfast sausage, casings removed if needed',
#    '1 cup unsalted butter (2 sticks), plus more for pan',
#    '2 medium onions, chopped',
#    '4 celery stalks, chopped',
#    'Kosher salt',
#    '3 garlic cloves, finely chopped',
#    '2 Thai chiles or 1 jalapeño (with seeds), chopped',
#    '¾ cup corn nuts, finely ground in a food processor, blender, or mortar and pestle (about ½ cup)',
#    '¾ cup dry white wine',
#    '1 Tbsp. finely chopped sage',
#    '2 tsp. finely chopped thyme',
#    '3 large eggs',
#    'Freshly ground black pepper',
#    '3½ cups turkey stock or low-sodium chicken broth'],
#   'nutrition': {'cal': 832,
#    'carb': '72 g(24%)',
#    'fat': '48 g(75%)',
#    'protein': '25 g(50%)',
#    'sat_fat': '20 g(99%)',
#    'sodium': '1594 mg(66%)',
#    'polyunsat_fat': '9 g',
#    'fiber': '2 g(7%)',
#    'monounsat_fat': '16 g',
#    'cholesterol': '209 mg(70%)',
#    'servings': 'per serving (10 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'occasion': ['thanksgiving', 'fall'],
#    'meal': ['side'],
#    'type': ['stuffing-dressing'],
#    'ingredient': ['sausage',
#     'chile-pepper',
#     'celery',
#     'sage',
#     'thyme',
#     'onion'],
#    'special-consideration': ['dairy-free',
#     'tree-nut-free',
#     'peanut-free',
#     'soy-free']}},
#  {'url': 'https://www.epicurious.com/recipes/food/views/coconut-creamed-greens',
#   'title': 'Coconut Creamed Greens ',
#   'author': 'Andy Baraghani',
#   'date': 'November 2019',
#   'month': 'November',
#   'year': 2019,
#   'rating': 0.0,
#   'reviews': 0,
#   'make_again': '0%',
#   'active_time': None,
#   'image_url': 'https://assets.epicurious.com/photos/5dd30095d482f10008d4fb27/6:4/w_274%2Ch_169/Coconut_creamed_greens_recipe_BA_111819.jpg',
#   'ingredients': ['1 cup unsweetened coconut flakes',
#    '3 lb. mixed hardy greens (such as Tuscan kale, curly kale, Swiss chard, and/or mustard greens; about 4 bunches)',
#    '¼ cup virgin coconut oil',
#    '6 garlic cloves, lightly crushed',
#    '1 large onion, finely chopped',
#    '1 red Thai or Fresno chile, thinly sliced',
#    '1 (2-inch) piece ginger, peeled, thinly sliced',
#    'Kosher salt',
#    '2 Tbsp. mustard seeds',
#    '2 tsp. ground coriander',
#    '½ tsp. ground turmeric',
#    '2 cups unsweetened coconut milk',
#    '½ cup coarsely chopped cilantro'],
#   'nutrition': {'cal': 302,
#    'carb': '16 g(5%)',
#    'fat': '27 g(41%)',
#    'protein': '6 g(12%)',
#    'sat_fat': '23 g(114%)',
#    'sodium': '377 mg(16%)',
#    'polyunsat_fat': '1 g',
#    'fiber': '6 g(22%)',
#    'monounsat_fat': '2 g',
#    'cholesterol': '',
#    'servings': 'per serving (8 servings)'},
#   'tags': {'source': ['bon-appetit'],
#    'meal': ['side'],
#    'occasion': ['thanksgiving', 'fall', 'winter'],
#    'ingredient': ['collard-greens',
#     'mustard-greens',
#     'kale',
#     'garlic',
#     'chile-pepper',
#     'coconut',
#     'ginger',
#     'coriander',
#     'cilantro'],
#    'special-consideration': ['vegetarian',
#     'vegan',
#     'wheat-gluten-free',
#     'dairy-free',
#     'soy-free',
#     'tree-nut-free']}}]

# %%
df_recipe_list.head(60)
# Out:
#        source  year                                              title  \
# 0   editorial  2019  Okonomiyaki (“As You Like It”) Pancakes With B...
# 1   editorial  2019       Salmon Confit with Lime, Juniper, and Fennel
# 2   editorial  2019  Coconut-Braised Chickpeas with Sweet Potatoes ...
# 3   editorial  2019                          Crispy Sheet-Pan Broccoli
# 4   editorial  2019                                       Prawn Moilee
# 5   editorial  2019                   Cardamom-Pistachio Bûche de Noël
# 6   editorial  2019                                       Tonnato Eggs
# 7   editorial  2019                          Chickpea-Mushroom Burgers
# 8   editorial  2019                    Kimchi Soup With Tofu and Clams
# 9   editorial  2019  Roasted Cabbage Steaks With Crispy Chickpeas a...
# 10  editorial  2019         Creamy Squash Risotto With Toasted Pepitas
# 11  editorial  2019                          Winter Salad Hummus Bowls
# 12  editorial  2019                               Seedy Power Sprinkle
# 13  editorial  2019                                        Salad Pasta
# 14  editorial  2019                               Martini-on-the-Rocks
# 15  editorial  2019                                         Oystertini
# 16  editorial  2019                                   Puritan Cocktail
# 17  editorial  2019                                       Tuxedo No. 2
# 18  editorial  2019                                  Obituary Cocktail
# 19  editorial  2019                                Classic Dry Martini
# 20  editorial  2019           Chilaquiles With Bacon, Eggs, and Cheese
# 21  editorial  2019                  Instant Pot Tequila Lime Carnitas
# 22  editorial  2019             Instant Pot Chicken Parmesan Meatballs
# 23  editorial  2019                             Spicy Chickpea Poppers
# 24  editorial  2019                                      Pandora’s Box
# 25  editorial  2019                                    Islay and Olive
# 26  editorial  2019                                        Sneaky Peat
# 27  editorial  2019    Pansit Palabok (Rice Noodles with Shrimp Sauce)
# 28  editorial  2019                     Bubble and Squeak With Stilton
# 29  editorial  2019           Spiced Pomegranate and Orange Glazed Ham
# 30  editorial  2019                                     Christmas Cake
# 31  editorial  2019                    Super-Simple Overnight Porridge
# 32  editorial  2019         A Feast of the Seven Fishes Cocktail Party
# 33  editorial  2019                             Sourdough Rye Brownies
# 34  editorial  2019                            Smoked Trout Croquettes
# 35  editorial  2019                              Smoked Salmon Tartare
# 36  editorial  2019                      Vanilla Butter Anchovy Toasts
# 37  editorial  2019                                             Lavash
# 38  editorial  2019  Coconut Cabbage and Tofu With Lemongrass and G...
# 39  editorial  2019                              Pecan-Rye Pumpkin Pie
# 40  editorial  2019                                 Lemon Meringue Pie
# 41  editorial  2019                              Chocolate Pudding Pie
# 42  editorial  2019                              Blind-Baked Pie Crust
# 43  editorial  2019                                   Banana Cream Pie
# 44  editorial  2019                            Why-Is-It-So-Good Gravy
# 45  editorial  2019                              Fancy Cranberry Sauce
# 46  editorial  2019             Squash and Radicchio Salad With Pecans
# 47  editorial  2019          Mashed Potatoes With Crispety Cruncheties
# 48  editorial  2019             Glazed Leeks With Pine Nut Salsa Verde
# 49  editorial  2019      Cornbread Stuffing With Sausage and Corn Nuts
# 50  editorial  2019                             Coconut Creamed Greens
# 51  editorial  2019                              Cheesy Cabbage Gratin
# 52  editorial  2019  Charred Sweet Potatoes With Hot Honey Butter a...
# 53  editorial  2019                             Buttery Bejeweled Rice
# 54  editorial  2019          Brussels Sprouts With Pistachios and Lime
# 55  editorial  2019             Broccolini With Sesame Sauce and Lemon
# 56  editorial  2019                                  White Pesto Pasta
# 57  editorial  2019                     Salmon with Citrus-Chile Sauce
# 58  editorial  2019                  Feel-Better Chicken and Rice Soup
# 59  editorial  2019                                     Applejack Sour
#
#                                                   url is_recipe scraped
# 0   /recipes/food/views/okonomiyaki-as-you-like-it...         1       1
# 1   /recipes/food/views/salmon-confit-with-lime-ju...         1       1
# 2   /recipes/food/views/coconut-braised-chickpeas-...         1       1
# 3       /recipes/food/views/crispy-sheet-pan-broccoli         1       1
# 4   /recipes/food/views/prawn-moilee-south-indian-...         1       1
# 5   /recipes/food/views/cardamom-pistachio-buche-d...         1       1
# 6                    /recipes/food/views/tonatto-eggs         1       1
# 7       /recipes/food/views/chickpea-mushroom-burgers         1       1
# 8   /recipes/food/views/kimchi-soup-with-tofu-and-...         1       1
# 9   /recipes/food/views/roasted-cabbage-steaks-wit...         1       1
# 10  /recipes/food/views/creamy-squash-risotto-with...         1       1
# 11      /recipes/food/views/winter-salad-hummus-bowls         1       1
# 12           /recipes/food/views/seedy-power-sprinkle         1       1
# 13                    /recipes/food/views/salad-pasta         1       1
# 14  /recipes/food/views/martini-on-the-rocks-easy-...         1       1
# 15  /recipes/food/views/oystertini-oyster-martini-...         1       1
# 16  /recipes/food/views/puritan-cocktail-martini-v...         1       1
# 17  /recipes/food/views/tuxedo-no-2-martini-cockta...         1       1
# 18  /recipes/food/views/obituary-cocktail-martini-...         1       1
# 19     /recipes/food/views/classic-dry-martini-237574         1       1
# 20  /recipes/food/views/chilaquiles-with-bacon-egg...         1       1
# 21  /recipes/food/views/instant-pot-tequila-lime-c...         1       1
# 22  /recipes/food/views/instant-pot-chicken-parmes...         1       1
# 23         /recipes/food/views/spicy-chickpea-poppers         1       1
# 24  /recipes/food/views/pandoras-box-shibuya-honey...         1       1
# 25  /recipes/food/views/islay-and-olive-batched-di...         1       1
# 26  /recipes/food/views/sneaky-peat-cranberry-scot...         1       1
# 27  /recipes/food/views/pansit-palabok-rice-noodle...         1       1
# 28  /recipes/food/views/bubble-and-squeak-with-sti...         1       1
# 29  /recipes/food/views/spiced-pomegranate-and-ora...         1       1
# 30           /recipes/food/views/christmas-fruit-cake         1       1
# 31  /recipes/food/views/overnight-porridge-congee-...         1       1
# 32  /holidays-events/a-feast-of-the-seven-fishes-c...         0
# 33         /recipes/food/views/sourdough-rye-brownies         1       1
# 34        /recipes/food/views/smoked-trout-croquettes         1       1
# 35          /recipes/food/views/smoked-salmon-tartare         1       1
# 36  /recipes/food/views/vanilla-butter-anchovy-toasts         1       1
# 37                         /recipes/food/views/lavash         1       1
# 38  /recipes/food/views/coconut-cabbage-and-tofu-w...         1       1
# 39          /recipes/food/views/pecan-rye-pumpkin-pie         1       1
# 40             /recipes/food/views/lemon-meringue-pie         1       1
# 41          /recipes/food/views/chocolate-pudding-pie         1       1
# 42          /recipes/food/views/blind-baked-pie-crust         1       1
# 43               /recipes/food/views/banana-cream-pie         1       1
# 44        /recipes/food/views/why-is-it-so-good-gravy         1       1
# 45          /recipes/food/views/fancy-cranberry-sauce         1       1
# 46  /recipes/food/views/squash-and-radicchio-salad...         1       1
# 47  /recipes/food/views/mashed-potatoes-with-crisp...         1       1
# 48  /recipes/food/views/glazed-leeks-with-pine-nut...         1       1
# 49  /recipes/food/views/cornbread-stuffing-with-sa...         1       1
# 50         /recipes/food/views/coconut-creamed-greens         1       1
# 51          /recipes/food/views/cheesy-cabbage-gratin
# 52  /recipes/food/views/charred-sweet-potatoes-wit...
# 53         /recipes/food/views/buttery-bejeweled-rice
# 54  /recipes/food/views/brussels-sprouts-with-pist...
# 55  /recipes/food/views/broccolini-with-sesame-sau...
# 56              /recipes/food/views/white-pesto-pasta
# 57  /recipes/food/views/salmon-with-citrus-chile-s...
# 58  /recipes/food/views/feel-better-chicken-and-ri...
# 59        /recipes/food/views/applejack-sour-cocktail

# %%
all_recipes.append(recipe)
with open('resources/data/all_recipe.json', 'w') as f:
    json.dump(all_recipes, f)

# %%
df_recipe_list.count()

# %%
url = "https://www.epicurious.com/recipes/food/views/okonomiyaki-as-you-like-it-pancakes-with-bonito-flakes"
r = requests.get(url)

# %%
r.status_code == 200

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
# parse with beautiful soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
ingredient_list = soup.find_all('li', class_="ingredient")

# %%
for ingredient_item in ingredient_list:
    print(ingredient_item.text)
